# %%
import numpy as np
import itertools
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.metrics import classification_report

# Ganti 'seaborn-poster' dengan style yang tersedia, misal 'seaborn-darkgrid'
plt.style.use('seaborn-darkgrid')

# 1
# 2
# 3
# 4
# 5


            
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\fadhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File c:\Users\fadhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:903, in _rc_params_in_file(fname, transform, fail_on_error)
#     902 rc_temp = {}
# --> 903 with _open_file_or_url(fname) as fd:
#     904     try:
#
# File c:\Users\fadhi\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File c:\Users\fadhi\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\__init__.py:880, in _open_file_or_url(fname)
# ...

# %%
# import the iris data
iris = datasets.load_iris()

print(iris.feature_names)
# only print the first 10 samples
print(iris.data[:10])
print('We have %d data samples with %d \
    features'%(iris.data.shape[0], iris.data.shape[1]))
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]]
# We have 150 data samples with 4     features

# %%
print(iris.target_names)
print(set(iris.target))
# Out:
# ['setosa' 'versicolor' 'virginica']
# {0, 1, 2}

# %%
# let's just use two features, so that we can 
# easily visualize them
X = iris.data[:, [0, 2]]
y = iris.target
target_names = iris.target_names
feature_names = iris.feature_names
# get the classes
n_class = len(set(y))
print('We have %d classes in the data'%(n_class))
# Out:
# We have 3 classes in the data

# %%
# let's have a look of the data first
colors = ['b', 'g', 'r']
symbols = ['o', '^', '*']
plt.figure(figsize = (10,8))
for i, c, s in (zip(range(n_class), colors, symbols)):
    ix = y == i
    plt.scatter(X[:, 0][ix], X[:, 1][ix], \
                color = c, marker = s, s = 60, \
                label = target_names[i])

plt.legend(loc = 2, scatterpoints = 1)
plt.xlabel('Feature 1 - ' + feature_names[0])
plt.ylabel('Feature 2 - ' + feature_names[2])
plt.show()

# %%
### Cara Install Git di Windows

1. Buka https://git-scm.com/download/win di browser.
2. Download installer Git untuk Windows (file `.exe`).
3. Jalankan file installer yang sudah diunduh.
4. Ikuti petunjuk instalasi, klik "Next" pada setiap langkah (opsi default sudah cukup untuk kebanyakan pengguna).
5. Setelah selesai, buka Command Prompt dan ketik `git --version` untuk memastikan Git sudah terpasang.

Git siap digunakan di Windows.
